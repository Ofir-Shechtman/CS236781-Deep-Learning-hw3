# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from it's latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labels faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236781.plot as plot
import cs236781.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236781.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File C:\Users\ofir5\.pytorch-datasets\lfw-bush.zip exists, skipping download.
# Extracting C:\Users\ofir5\.pytorch-datasets\lfw-bush.zip...
# Extracted 531 to C:\Users\ofir5\.pytorch-datasets\lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(15,10), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a model with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a model with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{Z}=\bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) =
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder model, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we maximize the evidence distribution, $p(\bb{X})$ (see question below).
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# Although this expectation is intractable,
# we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO", shown in the lecture):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) \right]
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(128, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#     (7): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
# )
# torch.Size([1, 1024, 8, 8])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This can be a CNN which is like a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions. Note that the decoder doesn't have to be exactly the opposite of the encoder and you can experiment with using a different architecture.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): ConvTranspose2d(1024, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ConvTranspose2d(1024, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): ConvTranspose2d(512, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): Conv2d(128, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (10): Tanh()
#   )
# )
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1C84FA47CA0>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Notice that we model the **log** of the variance, not the actual variance.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')
# Out:
# torch.Size([1024, 8, 8]) torch.Size([3, 64, 64]) 2
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv2d(128, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (7): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (8): ReLU()
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): ConvTranspose2d(1024, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): ConvTranspose2d(1024, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): ConvTranspose2d(512, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (7): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Conv2d(128, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (10): Tanh()
#     )
#   )
#   (encoder_fc): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=65536, out_features=1024, bias=False)
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (decoder_fc): Sequential(
#     (0): Linear(in_features=2, out_features=65536, bias=False)
#     (1): BatchNorm1d(65536, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Unflatten(unflattened_size=torch.Size([1024, 8, 8]))
#   )
#   (l_mu): Linear(in_features=1024, out_features=2, bias=True)
#   (l_var): Linear(in_features=1024, out_features=2, bias=True)
# )
# mu(x0)=[-0.051847328, -0.024523798], sigma2(x0)=[2.8978438, 2.8358943]

# %% [markdown]
# Let's sample some 2d latent representations for an input image `x0` and visualize them.

# %%
# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(N):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the mu/sigma in the previous block above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# sampled mu tensor([-0.1460, -0.0667])
# sampled sigma2 tensor([1.0694, 1.1974])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$ using the decoder CNN.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1C84F509700>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2 d_x} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x}),
# $$
#
# where $d_z$ is the dimension of the latent space, $d_x$ is the dimension of the input and $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$.
# This pointwise loss is the quantity that we'll compute and minimize with gradient descent.
# The first term corresponds to the data-reconstruction loss, while the second term corresponds to the KL-divergence loss.
# Note that the scaling by $d_x$ is not derived from the original loss formula and was added directly to the pointwise loss just to normalize the data term.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 58.3234367, delta=1e-3)
    return loss

test_vae_loss()
# Out:
# tensor(58.3234)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a isotropic Gaussian prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module. Make sure to implement the `checkpoints` feature of the `Trainer` class if you haven't done so already in Part 1.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparams()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), bias=False)
#       (7): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (8): ReLU()
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): ConvTranspose2d(256, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1), bias=False)
#       (7): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Conv2d(64, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (10): Tanh()
#     )
#   )
#   (encoder_fc): Sequential(
#     (0): Flatten()
#     (1): Linear(in_features=16384, out_features=1024, bias=False)
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (decoder_fc): Sequential(
#     (0): Linear(in_features=128, out_features=16384, bias=False)
#     (1): BatchNorm1d(16384, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Unflatten(unflattened_size=torch.Size([256, 8, 8]))
#   )
#   (l_mu): Linear(in_features=1024, out_features=128, bias=True)
#   (l_var): Linear(in_features=1024, out_features=128, bias=True)
# )
# {'batch_size': 53, 'h_dim': 256, 'z_dim': 128, 'x_sigma2': 2, 'learn_rate': 0.001, 'betas': (0.9, 0.999)}

# %% [markdown]
# **TODO**:
# 1. Run the following block to train. It will sample some images from your model every few epochs so you can see the progress.
# 2. When you're satisfied with your results, rename the checkpoints file by adding `_final`. When you run the `main.py` script to generate your submission, the final checkpoints file will be loaded instead of running training. Note that your final submission zip will not include the `checkpoints/` folder. This is OK.
#
# The images you get should be colorful, with different backgrounds and poses.

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)
        
if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=None, print_every=5,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 48.450, Accuracy 9.9): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.63s/it]
# test_batch (Avg. Loss 12.207, Accuracy 10.5): 100%|██████████████████████████████████████| 1/1 [00:01<00:00,  1.37s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 1
# train_batch (Avg. Loss 5.494, Accuracy 12.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.04s/it]
# test_batch (Avg. Loss 3.924, Accuracy 13.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 2
# train_batch (Avg. Loss 2.331, Accuracy 13.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.04s/it]
# test_batch (Avg. Loss 1.773, Accuracy 13.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 3
# train_batch (Avg. Loss 1.382, Accuracy 13.4): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 1.384, Accuracy 13.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 4
# train_batch (Avg. Loss 0.986, Accuracy 13.5): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.45s/it]
# test_batch (Avg. Loss 1.050, Accuracy 14.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 5
# train_batch (Avg. Loss 0.789, Accuracy 13.9): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.15s/it]
# test_batch (Avg. Loss 0.975, Accuracy 14.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.21s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 6
# train_batch (Avg. Loss 0.665, Accuracy 14.3): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.37s/it]
# test_batch (Avg. Loss 0.936, Accuracy 14.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.29s/it]
# train_batch (Avg. Loss 0.606, Accuracy 14.4): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.27s/it]
# test_batch (Avg. Loss 0.778, Accuracy 14.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.16s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 8
# train_batch (Avg. Loss 0.582, Accuracy 14.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.29s/it]
# test_batch (Avg. Loss 0.699, Accuracy 15.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 9
# train_batch (Avg. Loss 0.516, Accuracy 15.7): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.04s/it]
# test_batch (Avg. Loss 0.631, Accuracy 15.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.18s/it]
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 0.479, Accuracy 15.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.03s/it]
# test_batch (Avg. Loss 0.575, Accuracy 16.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 0.464, Accuracy 16.1): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.563, Accuracy 15.2): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.00it/s]
# train_batch (Avg. Loss 0.426, Accuracy 16.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.592, Accuracy 15.7): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.03it/s]
# train_batch (Avg. Loss 0.423, Accuracy 16.9): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.565, Accuracy 16.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.388, Accuracy 17.5): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.95s/it]
# test_batch (Avg. Loss 0.487, Accuracy 16.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 15
# train_batch (Avg. Loss 0.391, Accuracy 17.6): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.486, Accuracy 15.4): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.01it/s]
# train_batch (Avg. Loss 0.357, Accuracy 17.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.01s/it]
# test_batch (Avg. Loss 0.470, Accuracy 16.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.348, Accuracy 18.0): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.406, Accuracy 16.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 18
# train_batch (Avg. Loss 0.329, Accuracy 18.6): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# test_batch (Avg. Loss 0.433, Accuracy 17.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 19
# train_batch (Avg. Loss 0.335, Accuracy 18.0): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.95s/it]
# test_batch (Avg. Loss 0.422, Accuracy 18.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 20
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 0.325, Accuracy 18.7): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# test_batch (Avg. Loss 0.410, Accuracy 16.7): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.03it/s]
# train_batch (Avg. Loss 0.316, Accuracy 18.9): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.393, Accuracy 18.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.26s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 22
# train_batch (Avg. Loss 0.308, Accuracy 19.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.04s/it]
# test_batch (Avg. Loss 0.358, Accuracy 18.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.293, Accuracy 19.5): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# test_batch (Avg. Loss 0.440, Accuracy 18.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 24
# train_batch (Avg. Loss 0.283, Accuracy 19.2): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.338, Accuracy 16.5): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.01it/s]
# train_batch (Avg. Loss 0.277, Accuracy 19.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.398, Accuracy 17.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.282, Accuracy 18.8): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.342, Accuracy 16.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.263, Accuracy 20.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.330, Accuracy 17.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.260, Accuracy 20.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# test_batch (Avg. Loss 0.293, Accuracy 16.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.256, Accuracy 20.9): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.351, Accuracy 17.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 0.251, Accuracy 20.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.336, Accuracy 18.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 31
# train_batch (Avg. Loss 0.271, Accuracy 19.9): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.20s/it]
# test_batch (Avg. Loss 0.318, Accuracy 18.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.249, Accuracy 20.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.95s/it]
# test_batch (Avg. Loss 0.310, Accuracy 19.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 33
# train_batch (Avg. Loss 0.230, Accuracy 21.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# test_batch (Avg. Loss 0.272, Accuracy 18.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.226, Accuracy 21.4): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.331, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 35
# train_batch (Avg. Loss 0.226, Accuracy 21.5): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# test_batch (Avg. Loss 0.282, Accuracy 20.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 36
# train_batch (Avg. Loss 0.232, Accuracy 21.2): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.93s/it]
# test_batch (Avg. Loss 0.278, Accuracy 20.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 37
# train_batch (Avg. Loss 0.235, Accuracy 21.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.03s/it]
# test_batch (Avg. Loss 0.267, Accuracy 17.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.228, Accuracy 21.0): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# test_batch (Avg. Loss 0.303, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.228, Accuracy 21.0): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.00s/it]
# test_batch (Avg. Loss 0.265, Accuracy 19.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 0.241, Accuracy 20.8): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.94s/it]
# test_batch (Avg. Loss 0.317, Accuracy 18.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.216, Accuracy 21.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.266, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.205, Accuracy 22.7): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  3.00s/it]
# test_batch (Avg. Loss 0.295, Accuracy 18.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.224, Accuracy 21.3): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.13s/it]
# test_batch (Avg. Loss 0.287, Accuracy 18.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.212, Accuracy 22.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.275, Accuracy 17.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.215, Accuracy 21.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.280, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# train_batch (Avg. Loss 0.241, Accuracy 20.4): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.316, Accuracy 18.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.230, Accuracy 21.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# test_batch (Avg. Loss 0.266, Accuracy 18.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# train_batch (Avg. Loss 0.213, Accuracy 22.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.263, Accuracy 19.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.29s/it]
# train_batch (Avg. Loss 0.213, Accuracy 22.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.283, Accuracy 15.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 0.214, Accuracy 23.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.322, Accuracy 12.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# train_batch (Avg. Loss 0.235, Accuracy 20.6): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.276, Accuracy 18.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.219, Accuracy 22.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.269, Accuracy 17.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.199, Accuracy 22.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.265, Accuracy 17.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.202, Accuracy 22.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.250, Accuracy 20.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 55
# train_batch (Avg. Loss 0.200, Accuracy 22.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.10s/it]
# test_batch (Avg. Loss 0.242, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.188, Accuracy 23.7): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.243, Accuracy 21.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 57
# train_batch (Avg. Loss 0.189, Accuracy 23.6): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.03s/it]
# test_batch (Avg. Loss 0.221, Accuracy 20.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.184, Accuracy 23.8): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.256, Accuracy 18.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.193, Accuracy 24.0): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.249, Accuracy 15.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 0.180, Accuracy 23.8): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.248, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# train_batch (Avg. Loss 0.184, Accuracy 23.6): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.245, Accuracy 18.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.194, Accuracy 22.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.252, Accuracy 21.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 63
# train_batch (Avg. Loss 0.185, Accuracy 24.3): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.253, Accuracy 18.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.187, Accuracy 23.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.243, Accuracy 17.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/it]
# train_batch (Avg. Loss 0.212, Accuracy 22.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.10s/it]
# test_batch (Avg. Loss 0.248, Accuracy 16.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.209, Accuracy 22.4): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.230, Accuracy 18.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.205, Accuracy 22.7): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.238, Accuracy 19.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.195, Accuracy 23.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.237, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.199, Accuracy 24.0): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.12s/it]
# test_batch (Avg. Loss 0.254, Accuracy 17.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 0.197, Accuracy 22.9): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.11s/it]
# test_batch (Avg. Loss 0.228, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.188, Accuracy 24.6): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.229, Accuracy 18.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.180, Accuracy 24.8): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.206, Accuracy 21.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 73
# train_batch (Avg. Loss 0.184, Accuracy 24.4): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.03s/it]
# test_batch (Avg. Loss 0.237, Accuracy 20.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.165, Accuracy 25.4): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.07s/it]
# test_batch (Avg. Loss 0.200, Accuracy 21.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.161, Accuracy 25.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.223, Accuracy 22.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 76
# train_batch (Avg. Loss 0.163, Accuracy 25.7): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.04s/it]
# test_batch (Avg. Loss 0.195, Accuracy 22.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 77
# train_batch (Avg. Loss 0.163, Accuracy 25.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.246, Accuracy 22.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.175, Accuracy 25.2): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.211, Accuracy 19.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.174, Accuracy 25.0): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.05s/it]
# test_batch (Avg. Loss 0.198, Accuracy 20.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 0.156, Accuracy 26.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.11s/it]
# test_batch (Avg. Loss 0.198, Accuracy 21.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.157, Accuracy 25.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.201, Accuracy 19.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.160, Accuracy 25.4): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.186, Accuracy 22.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 83
# train_batch (Avg. Loss 0.183, Accuracy 24.0): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.201, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.170, Accuracy 24.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.184, Accuracy 22.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.183, Accuracy 24.5): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.223, Accuracy 19.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.16s/it]
# train_batch (Avg. Loss 0.168, Accuracy 26.3): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.13s/it]
# test_batch (Avg. Loss 0.202, Accuracy 20.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.166, Accuracy 25.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.256, Accuracy 16.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.167, Accuracy 26.5): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.205, Accuracy 19.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.155, Accuracy 26.8): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.08s/it]
# test_batch (Avg. Loss 0.226, Accuracy 18.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 0.180, Accuracy 24.5): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.11s/it]
# test_batch (Avg. Loss 0.247, Accuracy 14.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# train_batch (Avg. Loss 0.195, Accuracy 23.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.348, Accuracy 11.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# train_batch (Avg. Loss 0.215, Accuracy 24.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.15s/it]
# test_batch (Avg. Loss 0.265, Accuracy 17.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.184, Accuracy 25.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.11s/it]
# test_batch (Avg. Loss 0.224, Accuracy 19.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.165, Accuracy 26.0): 100%|██████████████████████████████████████| 9/9 [00:34<00:00,  3.79s/it]
# test_batch (Avg. Loss 0.192, Accuracy 21.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.149, Accuracy 27.3): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.60s/it]
# test_batch (Avg. Loss 0.203, Accuracy 20.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.150, Accuracy 27.3): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.200, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/it]
# train_batch (Avg. Loss 0.162, Accuracy 26.4): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.41s/it]
# test_batch (Avg. Loss 0.224, Accuracy 22.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.23s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 98
# train_batch (Avg. Loss 0.166, Accuracy 25.1): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.38s/it]
# test_batch (Avg. Loss 0.239, Accuracy 16.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.178, Accuracy 26.1): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.30s/it]
# test_batch (Avg. Loss 0.219, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 0.160, Accuracy 27.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.187, Accuracy 20.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.158, Accuracy 27.3): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.37s/it]
# test_batch (Avg. Loss 0.196, Accuracy 22.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.166, Accuracy 26.9): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.99s/it]
# test_batch (Avg. Loss 0.198, Accuracy 19.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.164, Accuracy 27.4): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.226, Accuracy 20.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.147, Accuracy 29.1): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# test_batch (Avg. Loss 0.181, Accuracy 22.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.191, Accuracy 24.7): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.67s/it]
# test_batch (Avg. Loss 0.235, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.52s/it]
# train_batch (Avg. Loss 0.176, Accuracy 27.5): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.40s/it]
# test_batch (Avg. Loss 0.206, Accuracy 22.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.33s/it]
# train_batch (Avg. Loss 0.177, Accuracy 25.6): 100%|██████████████████████████████████████| 9/9 [00:34<00:00,  3.81s/it]
# test_batch (Avg. Loss 0.196, Accuracy 22.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.29s/it]
# train_batch (Avg. Loss 0.166, Accuracy 26.8): 100%|██████████████████████████████████████| 9/9 [00:33<00:00,  3.67s/it]
# test_batch (Avg. Loss 0.208, Accuracy 18.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.25s/it]
# train_batch (Avg. Loss 0.167, Accuracy 27.3): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.35s/it]
# test_batch (Avg. Loss 0.191, Accuracy 21.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 0.161, Accuracy 27.8): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.14s/it]
# test_batch (Avg. Loss 0.214, Accuracy 19.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.39s/it]
# train_batch (Avg. Loss 0.162, Accuracy 26.8): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.65s/it]
# test_batch (Avg. Loss 0.186, Accuracy 20.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.21s/it]
# train_batch (Avg. Loss 0.145, Accuracy 29.1): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.29s/it]
# test_batch (Avg. Loss 0.195, Accuracy 21.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.187, Accuracy 25.7): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  3.00s/it]
# test_batch (Avg. Loss 0.267, Accuracy 19.0): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.04it/s]
# train_batch (Avg. Loss 0.177, Accuracy 27.1): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.33s/it]
# test_batch (Avg. Loss 0.183, Accuracy 20.4): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.04it/s]
# train_batch (Avg. Loss 0.164, Accuracy 28.0): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.11s/it]
# test_batch (Avg. Loss 0.213, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.162, Accuracy 27.1): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.181, Accuracy 21.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.53s/it]
# train_batch (Avg. Loss 0.155, Accuracy 26.6): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.259, Accuracy 15.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# train_batch (Avg. Loss 0.188, Accuracy 25.8): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.97s/it]
# test_batch (Avg. Loss 0.229, Accuracy 19.2): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.01it/s]
# train_batch (Avg. Loss 0.164, Accuracy 27.8): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# test_batch (Avg. Loss 0.224, Accuracy 16.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 0.152, Accuracy 28.2): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.98s/it]
# test_batch (Avg. Loss 0.175, Accuracy 22.4): 100%|███████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# train_batch (Avg. Loss 0.156, Accuracy 28.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.211, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# train_batch (Avg. Loss 0.146, Accuracy 29.3): 100%|██████████████████████████████████████| 9/9 [00:26<00:00,  2.96s/it]
# test_batch (Avg. Loss 0.185, Accuracy 21.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
# train_batch (Avg. Loss 0.147, Accuracy 28.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.20s/it]
# test_batch (Avg. Loss 0.222, Accuracy 19.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.17s/it]
# train_batch (Avg. Loss 0.184, Accuracy 26.4): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.64s/it]
# test_batch (Avg. Loss 0.269, Accuracy 19.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.20s/it]
# train_batch (Avg. Loss 0.167, Accuracy 27.4): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.40s/it]
# test_batch (Avg. Loss 0.172, Accuracy 22.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 126
# train_batch (Avg. Loss 0.152, Accuracy 29.7): 100%|██████████████████████████████████████| 9/9 [00:36<00:00,  4.03s/it]
# test_batch (Avg. Loss 0.200, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.25s/it]
# train_batch (Avg. Loss 0.158, Accuracy 28.0): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.54s/it]
# test_batch (Avg. Loss 0.204, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/it]
# train_batch (Avg. Loss 0.178, Accuracy 27.5): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.47s/it]
# test_batch (Avg. Loss 0.237, Accuracy 18.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# train_batch (Avg. Loss 0.182, Accuracy 27.4): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.50s/it]
# test_batch (Avg. Loss 0.209, Accuracy 20.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 0.171, Accuracy 27.0): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.03s/it]
# test_batch (Avg. Loss 0.218, Accuracy 18.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.154, Accuracy 29.8): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.193, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.139, Accuracy 30.6): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.290, Accuracy 10.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.154, Accuracy 29.1): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.02s/it]
# test_batch (Avg. Loss 0.200, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# train_batch (Avg. Loss 0.164, Accuracy 27.9): 100%|██████████████████████████████████████| 9/9 [00:27<00:00,  3.09s/it]
# test_batch (Avg. Loss 0.185, Accuracy 20.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.155, Accuracy 28.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.17s/it]
# test_batch (Avg. Loss 0.184, Accuracy 22.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.18s/it]
# train_batch (Avg. Loss 0.141, Accuracy 30.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.27s/it]
# test_batch (Avg. Loss 0.171, Accuracy 21.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.130, Accuracy 31.5): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.15s/it]
# test_batch (Avg. Loss 0.161, Accuracy 22.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# train_batch (Avg. Loss 0.120, Accuracy 31.6): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.41s/it]
# test_batch (Avg. Loss 0.246, Accuracy 13.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/it]
# train_batch (Avg. Loss 0.158, Accuracy 28.8): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.29s/it]
# test_batch (Avg. Loss 0.192, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.24s/it]
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 0.151, Accuracy 30.5): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.24s/it]
# test_batch (Avg. Loss 0.177, Accuracy 21.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/it]
# train_batch (Avg. Loss 0.147, Accuracy 30.3): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.28s/it]
# test_batch (Avg. Loss 0.191, Accuracy 18.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.34s/it]
# train_batch (Avg. Loss 0.140, Accuracy 30.1): 100%|██████████████████████████████████████| 9/9 [00:32<00:00,  3.60s/it]
# test_batch (Avg. Loss 0.178, Accuracy 22.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# train_batch (Avg. Loss 0.135, Accuracy 32.1): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.23s/it]
# test_batch (Avg. Loss 0.188, Accuracy 21.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# train_batch (Avg. Loss 0.133, Accuracy 30.9): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.149, Accuracy 23.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 145
# train_batch (Avg. Loss 0.122, Accuracy 32.4): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.182, Accuracy 22.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.18s/it]
# train_batch (Avg. Loss 0.121, Accuracy 32.5): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.31s/it]
# test_batch (Avg. Loss 0.172, Accuracy 23.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 147
# train_batch (Avg. Loss 0.120, Accuracy 33.3): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.31s/it]
# test_batch (Avg. Loss 0.169, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.15s/it]
# train_batch (Avg. Loss 0.133, Accuracy 32.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.25s/it]
# test_batch (Avg. Loss 0.181, Accuracy 19.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# train_batch (Avg. Loss 0.136, Accuracy 31.8): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.159, Accuracy 23.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 0.129, Accuracy 32.6): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.23s/it]
# test_batch (Avg. Loss 0.168, Accuracy 22.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.124, Accuracy 34.3): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.29s/it]
# test_batch (Avg. Loss 0.190, Accuracy 22.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.151, Accuracy 30.8): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.27s/it]
# test_batch (Avg. Loss 0.175, Accuracy 21.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.17s/it]
# train_batch (Avg. Loss 0.160, Accuracy 30.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.188, Accuracy 19.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# train_batch (Avg. Loss 0.151, Accuracy 30.8): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.199, Accuracy 21.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.158, Accuracy 30.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.190, Accuracy 20.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.149, Accuracy 31.5): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.25s/it]
# test_batch (Avg. Loss 0.180, Accuracy 20.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.147, Accuracy 31.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.192, Accuracy 20.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.17s/it]
# train_batch (Avg. Loss 0.162, Accuracy 29.5): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.45s/it]
# test_batch (Avg. Loss 0.185, Accuracy 18.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.135, Accuracy 32.5): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.28s/it]
# test_batch (Avg. Loss 0.179, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/it]
# --- EPOCH 161/200 ---
# train_batch (Avg. Loss 0.131, Accuracy 33.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.25s/it]
# test_batch (Avg. Loss 0.221, Accuracy 14.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.22s/it]
# train_batch (Avg. Loss 0.135, Accuracy 32.4): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.35s/it]
# test_batch (Avg. Loss 0.167, Accuracy 21.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.15s/it]
# train_batch (Avg. Loss 0.129, Accuracy 32.4): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.23s/it]
# test_batch (Avg. Loss 0.166, Accuracy 20.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.14s/it]
# train_batch (Avg. Loss 0.133, Accuracy 32.8): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.23s/it]
# test_batch (Avg. Loss 0.195, Accuracy 19.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.128, Accuracy 33.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.23s/it]
# test_batch (Avg. Loss 0.159, Accuracy 21.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.139, Accuracy 34.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.24s/it]
# test_batch (Avg. Loss 0.190, Accuracy 19.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.19s/it]
# train_batch (Avg. Loss 0.222, Accuracy 25.9): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.25s/it]
# test_batch (Avg. Loss 0.258, Accuracy 18.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.186, Accuracy 28.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.25s/it]
# test_batch (Avg. Loss 0.177, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.16s/it]
# train_batch (Avg. Loss 0.144, Accuracy 31.6): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.43s/it]
# test_batch (Avg. Loss 0.162, Accuracy 22.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# train_batch (Avg. Loss 0.137, Accuracy 32.0): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.30s/it]
# test_batch (Avg. Loss 0.157, Accuracy 23.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.13s/it]
# --- EPOCH 171/200 ---
# train_batch (Avg. Loss 0.127, Accuracy 32.6): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.26s/it]
# test_batch (Avg. Loss 0.172, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.122, Accuracy 33.7): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.33s/it]
# test_batch (Avg. Loss 0.149, Accuracy 21.2): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.27s/it]
# train_batch (Avg. Loss 0.114, Accuracy 34.3): 100%|██████████████████████████████████████| 9/9 [00:31<00:00,  3.50s/it]
# test_batch (Avg. Loss 0.149, Accuracy 22.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.114, Accuracy 34.5): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.166, Accuracy 23.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.119, Accuracy 34.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.220, Accuracy 14.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.137, Accuracy 32.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.20s/it]
# test_batch (Avg. Loss 0.190, Accuracy 18.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.125, Accuracy 35.8): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.179, Accuracy 20.0): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# train_batch (Avg. Loss 0.123, Accuracy 34.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.16s/it]
# test_batch (Avg. Loss 0.186, Accuracy 22.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.134, Accuracy 32.7): 100%|██████████████████████████████████████| 9/9 [00:30<00:00,  3.34s/it]
# test_batch (Avg. Loss 0.196, Accuracy 19.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# train_batch (Avg. Loss 0.160, Accuracy 31.9): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.20s/it]
# test_batch (Avg. Loss 0.166, Accuracy 21.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# --- EPOCH 181/200 ---
# train_batch (Avg. Loss 0.143, Accuracy 32.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.17s/it]
# test_batch (Avg. Loss 0.161, Accuracy 19.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.189, Accuracy 32.5): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.274, Accuracy 19.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.14s/it]
# train_batch (Avg. Loss 0.215, Accuracy 29.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.251, Accuracy 13.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.10s/it]
# train_batch (Avg. Loss 0.162, Accuracy 31.3): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.18s/it]
# test_batch (Avg. Loss 0.196, Accuracy 21.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.11s/it]
# train_batch (Avg. Loss 0.147, Accuracy 31.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.17s/it]
# test_batch (Avg. Loss 0.164, Accuracy 20.5): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.12s/it]
# train_batch (Avg. Loss 0.128, Accuracy 33.9): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.192, Accuracy 19.1): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.141, Accuracy 32.7): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.167, Accuracy 20.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.16s/it]
# train_batch (Avg. Loss 0.160, Accuracy 32.0): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.17s/it]
# test_batch (Avg. Loss 0.157, Accuracy 23.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 188
# train_batch (Avg. Loss 0.138, Accuracy 33.1): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.192, Accuracy 17.8): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.133, Accuracy 33.6): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.21s/it]
# test_batch (Avg. Loss 0.150, Accuracy 23.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 190
# --- EPOCH 191/200 ---
# train_batch (Avg. Loss 0.129, Accuracy 35.1): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.21s/it]
# test_batch (Avg. Loss 0.174, Accuracy 19.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# train_batch (Avg. Loss 0.129, Accuracy 33.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.201, Accuracy 17.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.28s/it]
# train_batch (Avg. Loss 0.131, Accuracy 35.0): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.22s/it]
# test_batch (Avg. Loss 0.169, Accuracy 22.3): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.109, Accuracy 36.3): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.12s/it]
# test_batch (Avg. Loss 0.129, Accuracy 24.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# *** Saved checkpoint checkpoints/vae.pt at epoch 194
# train_batch (Avg. Loss 0.110, Accuracy 37.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.12s/it]
# test_batch (Avg. Loss 0.140, Accuracy 21.9): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.114, Accuracy 36.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.15s/it]
# test_batch (Avg. Loss 0.165, Accuracy 19.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.165, Accuracy 31.8): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.16s/it]
# test_batch (Avg. Loss 0.203, Accuracy 21.7): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.08s/it]
# train_batch (Avg. Loss 0.145, Accuracy 34.2): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.14s/it]
# test_batch (Avg. Loss 0.191, Accuracy 19.6): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# train_batch (Avg. Loss 0.126, Accuracy 36.2): 100%|██████████████████████████████████████| 9/9 [00:29<00:00,  3.29s/it]
# test_batch (Avg. Loss 0.175, Accuracy 20.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.14s/it]
# --- EPOCH 200/200 ---
# train_batch (Avg. Loss 0.129, Accuracy 34.4): 100%|██████████████████████████████████████| 9/9 [00:28<00:00,  3.19s/it]
# test_batch (Avg. Loss 0.167, Accuracy 22.4): 100%|███████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# *** Images Generated from best model:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236781.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)

# %% [markdown]
# ### Question 2
#
# 1. Explain the purpose of both parts of the VAE loss term - reconstruction loss and KL divergence loss.
# 2. How is the latent-space distribution affected by the KL loss term?
# 3. What's the benefit of this effect?

# %%
display_answer(hw3.answers.part2_q2)

# %% [markdown]
# ### Question 3
#
# In the formulation of the VAE loss, why do we start by maximizing the evidence
# distribution, $p(\bb{X})$?

# %%
display_answer(hw3.answers.part2_q3)

# %% [markdown]
# ### Question 4
#
# In the VAE encoder, why do we model the **log** of the
# latent-space variance corresponding to an input, $\bb{\sigma}^2_{\bb{\alpha}}$,
# instead of directly modelling this variance?

# %%
display_answer(hw3.answers.part2_q4)
